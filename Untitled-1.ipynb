# %%
import numpy as np

class board:
    def __init__(self):
        self.arr = np.zeros((3,3))
    def print(self):
        for i in self.arr:
            print(i)

b = board()
b.print()
# Out:
# [0. 0. 0.]
# [0. 0. 0.]
# [0. 0. 0.]
